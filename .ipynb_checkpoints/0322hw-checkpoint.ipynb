# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import geopandas as gpd

# %%
sheet_name_a = [10412,10512,10612,10712]
TPV104 = pd.read_excel('TP_vill_use2.xlsx' ,sheet_name=str(sheet_name_a[0]))
TPV105 = pd.read_excel('TP_vill_use2.xlsx' ,sheet_name=str(sheet_name_a[1]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a5370e62e49a> in <module>
#       1 sheet_name_a = [10412,10512,10612,10712]
# ----> 2 TPV104 = pd.read_excel('TP_vill_use2.xlsx' ,sheet_name=str(sheet_name_a[0]))
#       3 TPV105 = pd.read_excel('TP_vill_use2.xlsx' ,sheet_name=str(sheet_name_a[1]))
#       4 TPV106 = pd.read_excel('TP_vill_use2.xlsx' ,sheet_name=str(sheet_name_a[2]))
#       5 TPV107 = pd.read_excel('TP_vill_use2.xlsx' ,sheet_name=str(sheet_name_a[3]))
#
# D:\ProgramData\Anaconda\envs\snake\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# D:\ProgramData\Anaconda\envs\snake\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# D:\ProgramData\Anaconda\envs\snake\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, parse_cols, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     348
#     349     if not isinstance(io, ExcelFile):
# --> 350         io = ExcelFile(io, engine=engine)
#     351
#     352     return io.parse(
#
# D:\ProgramData\Anaconda\envs\snake\lib\site-packages\pandas\io\excel.py in __init__(self, io, engine)
#     651         self._io = _stringify_path(io)
#     652
# --> 653         self._reader = self._engines[engine](self._io)
#     654
#     655     def __fspath__(self):
#
# D:\ProgramData\Anaconda\envs\snake\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     422             self.book = xlrd.open_workbook(file_contents=data)
#     423         elif isinstance(filepath_or_buffer, compat.string_types):
# --> 424             self.book = xlrd.open_workbook(filepath_or_buffer)
#     425         else:
#     426             raise ValueError('Must explicitly set engine if not passing in'
#
# D:\ProgramData\Anaconda\envs\snake\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     136                 formatting_info=formatting_info,
#     137                 on_demand=on_demand,
# --> 138                 ragged_rows=ragged_rows,
#     139             )
#     140             return bk
#
# D:\ProgramData\Anaconda\envs\snake\lib\site-packages\xlrd\xlsx.py in open_workbook_2007_xml(zf, component_names, logfile, verbosity, use_mmap, formatting_info, on_demand, ragged_rows)
#     839         x12sheet = X12Sheet(sheet, logfile, verbosity)
#     840         heading = "Sheet %r (sheetx=%d) from %r" % (sheet.name, sheetx, fname)
# --> 841         x12sheet.process_stream(zflo, heading)
#     842         del zflo
#     843
#
# D:\ProgramData\Anaconda\envs\snake\lib\site-packages\xlrd\xlsx.py in own_process_stream(self, stream, heading)
#     546         row_tag = U_SSML12 + "row"
#     547         self_do_row = self.do_row
# --> 548         for event, elem in ET.iterparse(stream):
#     549             if elem.tag == row_tag:
#     550                 self_do_row(elem)
#
# D:\ProgramData\Anaconda\envs\snake\lib\xml\etree\ElementTree.py in iterator()
#    1224                 if not data:
#    1225                     break
# -> 1226                 pullparser.feed(data)
#    1227             root = pullparser._close_and_return_root()
#    1228             yield from pullparser.read_events()
#
# D:\ProgramData\Anaconda\envs\snake\lib\xml\etree\ElementTree.py in feed(self, data)
#    1266         if data:
#    1267             try:
# -> 1268                 self._parser.feed(data)
#    1269             except SyntaxError as exc:
#    1270                 self._events_queue.append(exc)
#
# D:\ProgramData\Anaconda\envs\snake\lib\xml\etree\ElementTree.py in feed(self, data)
#    1622         """Feed encoded data to parser."""
#    1623         try:
# -> 1624             self.parser.Parse(data, 0)
#    1625         except self._error as v:
#    1626             self._raiseerror(v)
#
# c:\ci\python_1550799517308\work\modules\pyexpat.c in StartElement()
#
# D:\ProgramData\Anaconda\envs\snake\lib\xml\etree\ElementTree.py in _start(self, tag, attr_list)
#    1540         # is set, the attributes are reported as a list of alternating
#    1541         # attribute name,value.
# -> 1542         fixname = self._fixname
#    1543         tag = fixname(tag)
#    1544         attrib = {}
#
# KeyboardInterrupt:
